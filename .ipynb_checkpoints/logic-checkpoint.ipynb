# %%
import random
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
% matplotlib inline

data = pd.read_csv("yeast_cell_data/yeast_cell_data.csv")

data.columns
data.dtypes
print("data shape: ",data.shape)
data.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# data shape:  (50, 5)
#                         raw_file                       cropped_file  alive  \
# 0  raw_files/20181115_110643.jpg  cropped_files/20181115_110643.jpg     12
# 1  raw_files/20181115_110619.jpg  cropped_files/20181115_110619.jpg     10
# 2  raw_files/20181115_110600.jpg  cropped_files/20181115_110600.jpg     11
# 3  raw_files/20181115_110541.jpg  cropped_files/20181115_110541.jpg      7
# 4  raw_files/20181115_110516.jpg  cropped_files/20181115_110516.jpg     10
#
#    dead            file_name
# 0     1  20181115_110643.jpg
# 1     0  20181115_110619.jpg
# 2     1  20181115_110600.jpg
# 3     1  20181115_110541.jpg
# 4     0  20181115_110516.jpg

# %%
from IPython.display import Image
Image(filename='yeast_cell_data/'+data['raw_file'][0])

# %%
from IPython.display import Image
Image(filename='yeast_cell_data/'+data['cropped_file'][0])

# %%
for i in range(6):
    j = random.randint(0, 49)
    im = plt.imread('yeast_cell_data/'+data['cropped_file'][j])
    fig = plt.figure(0, (20,16))
    fig.add_subplot(3,3,i+1)
    plt.grid(0)
    plt.imshow(im)
    plt.title('Alive: '+str(data['alive'][j])+'  Dead: '+str(data['dead'][j]));

# %%
training_indices = np.arange(40)
testing_indices = np.arange(40, 50)

images_training = data['cropped_file'][training_indices]
alive_training = data['alive'][training_indices]

images_testing = data['cropped_file'][testing_indices]
alive_testing = data['alive'][testing_indices]

# %%
#Hyper Parameters
learning_rate = 1e-4
num_iterations = 5000

#How many bins is our data encoded into:
bins = alive_training.shape[0]

#Setup tf placeholders for images and angles
im = tf.placeholder(tf.float32, (None, 60, 64))
ang = tf.placeholder(tf.float32, (None, bins))

#Reshape input images into vectors
im_reshaped = tf.reshape(im, (-1, 60*64))

#Hidden Layer
a1 = tf.layers.dense(im_reshaped, 4, activation = tf.sigmoid)

#Output layer
yhat = tf.layers.dense(a1, bins)

#Loss function
loss = tf.losses.mean_squared_error(ang, yhat)

#Optimizer
train_op = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(loss)

# %%
from IPython import display

#Store errors as we train in a list:
RMSEs = []

#Initialize Tensorflow session:
sess = tf.InteractiveSession()
tf.global_variables_initializer().run()

#And train!
for i in range(num_iterations):
    #Train Step
#     sess.run({im:(images_training), ang:alive_training})
    sess.run({im:tf.constant(images_training, dtype=tf.string), ang:tf.constant(alive_training, dtype=tf.int32)})
    #Measure error
    RMSEs.append(np.sqrt(loss.eval(feed_dict = {im:images_training, ang:alive_training})))

    #Visualize as we go!
    if i%25==0:
        clf(); fig = figure(0, (18, 9))
        plot(RMSEs, linewidth = 2)
        xlabel('Iterations'); ylabel('RMSE')
        display.clear_output(wait=True); display.display(gcf())
# Out:
# 0     12
# 1     10
# 2     11
# 3      7
# 4     10
# 5      8
# 6     11
# 7      8
# 8     10
# 9     15
# 10     9
# 11     8
# 12     6
# 13    15
# 14    12
# 15    12
# 16     5
# 17     6
# 18    11
# 19    13
# 20    13
# 21    10
# 22    21
# 23    23
# 24    19
# 25    21
# 26    25
# 27    24
# 28    18
# 29    21
# 30    16
# 31    17
# 32    21
# 33    17
# 34    20
# 35    24
# 36    24
# 37    14
# 38    20
# 39    19
# Name: alive, dtype: int64
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py:1645: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-da15cb6a95f8> in <module>()
#      13     print(alive_training)
#      14 #     sess.run({im:(images_training), ang:alive_training})
# ---> 15     sess.run({im:tf.constant(images_training, dtype=tf.string), ang:tf.constant(alive_training, dtype=tf.int32)})
#      16     #Measure error
#      17     RMSEs.append(np.sqrt(loss.eval(feed_dict = {im:images_training, ang:alive_training})))
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py in constant(value, dtype, shape, name, verify_shape)
#     194   tensor_value.tensor.CopyFrom(
#     195       tensor_util.make_tensor_proto(
# --> 196           value, dtype=dtype, shape=shape, verify_shape=verify_shape))
#     197   dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     198   const_tensor = g.create_op(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\tensor_util.py in make_tensor_proto(values, dtype, shape, verify_shape)
#     415     # If a class has the __array__ method, or __array_interface__ dict, then it
#     416     # is possible to convert to numpy array.
# --> 417     nparray = np.asarray(values, dtype=dtype)
#     418
#     419     # This is the preferred way to create an array from the object, so replace
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     490
#     491     """
# --> 492     return array(a, dtype, copy=False, order=order)
#     493
#     494
#
# TypeError: data type not understood
